# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Loading the dataset
data = pd.read_csv('data/bank-additional-full-preprocessed.csv')

# %%
data.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %% [markdown]
# __Visualizing All the categorical columns__

# %% [markdown]
# __Visualizing Age Distribution__

# %%
sns.histplot(x="age", data=data , kde=True, hue= "y")
plt.title("Age Distribution and Deposits\n")
plt.show()

# %% [markdown]
# __Visualizing Job Distribution__

# %%
plt.figure(figsize=(16,4))
sns.countplot(x="job", data= data, hue ="y")
plt.title("Occupation Distribution and Deposits\n")
plt.show()

# %% [markdown]
# __Visualizing martial status distribution__

# %%
plt.figure(figsize=(7,3))
sns.countplot(x="marital", data= data, hue ="y")
plt.title("Marital Status and Deposits\n")
plt.show()

# %% [markdown]
# Visualizing educational status

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="education", data= data, hue ="y")
plt.title("Education Status and Deposits\n")
plt.show()

# %% [markdown]
# __Visualizing default distribution__

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="default", data= data, hue ="y")
plt.title("Default Status and Deposits\n")
plt.show()

# %% [markdown]
# __Visualizing housing loan distribution__

# %%
plt.figure(figsize=(6,3.5))
sns.countplot(x="housing", data= data, hue ="y")
plt.title("Housing Loan Distribution and Deposits\n")
plt.show()

# %% [markdown]
# __Visualizing Personal loan distribution__

# %%
plt.figure(figsize=(6,3.5))
sns.countplot(x="loan", data= data, hue ="y")
plt.title("Personal Loan Distribution and Deposits\n")
plt.show()

# %% [markdown]
# __Visualizing Contact distribution__

# %%
plt.figure(figsize=(6,3.5))
sns.countplot(x="contact", data= data, hue ="y")
plt.title("Contact Distribution and Deposits\n")
plt.show()

# %% [markdown]
# __Visualizing Monthly Distribution__

# %%
plt.figure(figsize=(6,3.5))
sns.countplot(x="month", data= data, hue ="y")
plt.title("Monthly Distribution and Deposits\n")
plt.show()

# %% [markdown]
# __Visualizing day of the week distribution__

# %%
plt.figure(figsize=(6,3.5))
sns.countplot(x="day_of_week", data= data, hue ="y")
plt.title("Day of the week Distribution and Deposits\n")
plt.show()

# %% [markdown]
# __Outlier Detection__

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize each numerical column using boxplots
numerical_columns = ['age', 'campaign', 'pdays', 'previous',
                     'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

for column in numerical_columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(data[column])
    plt.title(f"Boxplot for {column}")
    plt.show()

# %% [markdown]
# __Visualizing correlation matrix__

# %%
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

cols = data.select_dtypes("object").columns

le = LabelEncoder()

data[cols] = data[cols].apply(le.fit_transform)

plt.figure(figsize=(23,10))
sns.heatmap(data.corr(), cmap='bwr', annot=True)
plt.show()
